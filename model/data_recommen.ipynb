# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\flask\dataset_recommendation system\kaggle-preprocessed.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                           Dataset_name        Author_name  \
# 0           0             Hotel Reservations Dataset         Ahsan Raza
# 1           2  Most Subscribed 1000 Youtube Channels  Mrityunjay Pathak
# 2           3  Olympics 124 years Dataset(till 2020)    Nitish Sharma01
# 3           4          Medical Student Mental Health     The Devastator
# 4           5     Latest Netflix TV shows and movies    Senapati Rajesh
#
#                                     Author_id  No_of_files    size  \
# 0              https://www.kaggle.com/ahsan81            1  491 kB
# 1  https://www.kaggle.com/themrityunjaypathak            1   29 kB
# 2       https://www.kaggle.com/nitishsharma01            3    5 MB
# 3        https://www.kaggle.com/thedevastator            2   19 kB
# 4       https://www.kaggle.com/senapatirajesh            1    1 MB
#
#   Type_of_file  Upvotes  Medals  Usability       Date  Day      Time  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9158 entries, 0 to 9157
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    9158 non-null   int64
#  1   Dataset_name  9158 non-null   object
#  2   Author_name   9158 non-null   object
#  3   Author_id     9158 non-null   object
#  4   No_of_files   9158 non-null   int64
#  5   size          9158 non-null   object
#  6   Type_of_file  9156 non-null   object
#  7   Upvotes       9158 non-null   int64
#  8   Medals        9158 non-null   object
#  9   Usability     9158 non-null   float64
#  10  Date          9158 non-null   object
#  11  Day           9158 non-null   object
#  12  Time          9158 non-null   object
#  13  Dataset_link  9158 non-null   object
# dtypes: float64(1), int64(3), object(10)
# memory usage: 1001.8+ KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Dataset_name    0
# Author_name     0
# Author_id       0
# No_of_files     0
# size            0
# Type_of_file    2
# Upvotes         0
# Medals          0
# Usability       0
# Date            0
# Day             0
# Time            0
# Dataset_link    0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Dataset_name    0
# Author_name     0
# Author_id       0
# No_of_files     0
# size            0
# Type_of_file    2
# Upvotes         0
# Medals          0
# Usability       0
# Date            0
# Day             0
# Time            0
# Dataset_link    0
# dtype: int64

# %%
df.drop('Unnamed: 0',axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9158 entries, 0 to 9157
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Dataset_name  9158 non-null   object
#  1   Author_name   9158 non-null   object
#  2   Author_id     9158 non-null   object
#  3   No_of_files   9158 non-null   int64
#  4   size          9158 non-null   object
#  5   Type_of_file  9156 non-null   object
#  6   Upvotes       9158 non-null   int64
#  7   Medals        9158 non-null   object
#  8   Usability     9158 non-null   float64
#  9   Date          9158 non-null   object
#  10  Day           9158 non-null   object
#  11  Time          9158 non-null   object
#  12  Dataset_link  9158 non-null   object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 930.2+ KB

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9156 entries, 0 to 9157
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Dataset_name  9156 non-null   object
#  1   Author_name   9156 non-null   object
#  2   Author_id     9156 non-null   object
#  3   No_of_files   9156 non-null   int64
#  4   size          9156 non-null   object
#  5   Type_of_file  9156 non-null   object
#  6   Upvotes       9156 non-null   int64
#  7   Medals        9156 non-null   object
#  8   Usability     9156 non-null   float64
#  9   Date          9156 non-null   object
#  10  Day           9156 non-null   object
#  11  Time          9156 non-null   object
#  12  Dataset_link  9156 non-null   object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 1001.4+ KB

# %%
df.describe()
# Out:
#         No_of_files       Upvotes    Usability
# count  9.156000e+03   9156.000000  9156.000000
# mean   5.758411e+03     73.435889     7.437331
# std    5.876357e+04    378.910703     2.763942
# min    1.000000e+00      0.000000     0.000000
# 25%    1.000000e+00      7.000000     5.900000
# 50%    2.000000e+00     23.000000     8.500000
# 75%    8.000000e+00     51.000000     9.700000
# max    3.999566e+06  27619.000000    10.000000

# %%
df['features'] = (
    df['Dataset_name'].astype(str) + " " +
    df['Author_name'].astype(str) + " " +
    df['Type_of_file'].astype(str) + " " +
    df['Medals'].astype(str) + " " +
    df['Day'].astype(str)
)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors
import joblib

# %%
vectorizer = TfidfVectorizer()
x = vectorizer.fit_transform(df['features'])

model = NearestNeighbors(n_neighbors=10, metric='cosine')
model.fit(x)
# Out:
# NearestNeighbors(metric='cosine', n_neighbors=10)

# %%
from sklearn.metrics.pairwise import cosine_similarity
import seaborn as sns
import matplotlib.pyplot as plt

similarity_matrix = cosine_similarity(x)

# Heatmap
sns.heatmap(similarity_matrix[:10, :10], annot=True, cmap="coolwarm")
plt.title("Cosine Similarity Heatmap (First 10 samples)")
plt.show()

# %%
joblib.dump(model,'model.pkl')
joblib.dump(vectorizer, 'vectorizer.pkl')
joblib.dump(df,'dataset.pkl')
# Out:
# ['dataset.pkl']
